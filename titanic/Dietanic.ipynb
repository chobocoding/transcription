# %% [markdown]
# # EDA To Prediction(DieTanic)
#
# https://www.kaggle.com/ash316/eda-to-prediction-dietanic
#
#
# ## Contents of the Notebook:
#
# ### Part1: Exploratory Data Analysis(EDA):
#
# 1)Analysis of the features.
#
# 2)Finding any relations or trends considering multiple features.
#
# ### Part2: Feature Engineering and Data Cleaning:
# 1)Adding any few features.
#
# 2)Removing redundant features.
#
# 3)Converting features into suitable form for modeling.
#
# ### Part3: Predictive Modeling
# 1)Running Basic Algorithms.
#
# 2)Cross Validation.
#
# 3)Ensembling.
#
# 4)Important Features Extraction.

# %% [markdown]
# # Part1: Exploratory Data Analysis(EDA):

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/캐글 필사/titanic/titanic/train.csv')

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
#
# [3 rows x 12 columns]

# %%
data.isnull().sum() # checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# The Age, Cabin, Embarked have null values

# How many survived??

f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)   # autopct 은 부채꼴 안에 표시될 숫자의 형식을 지정 소수점 두자리까지 표시하도록 설정

ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# # Types Of Features
#
# ## Categorical Features:
#
# A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables. They are also known as Nominal Variables.
#
# * Categorical Features in the dataset: Sex,Embarked.
#
# ## Ordinal Features:
#
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values. For eg: If we have a feature like Height with values Tall, Medium, Short, then Height is a ordinal variable. Here we can have a relative sort in the variable.
#
# * Ordinal Features in the dataset: PClass
#
# ## Continous Feature:
#
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.
#
# * Continous Features in the dataset: Age

# %% [markdown]
# # Analysing The Features
#
# Sex--> Categorical Feature

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data[['Sex', 'Survived']].groupby('Sex').mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')

sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex : Survived vs Dead')
plt.show()

# %% [markdown]
# Pclass --> Ordinal Feature

# %%
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row0_col0,#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row1_col1,#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row3_col0,#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row3_col1,#T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_d518c0ba_3ef1_11ec_a50f_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass : Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col0,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col1,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col3,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col2,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col1,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col0,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col1,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col2,#T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_ab7b71c0_3ef2_11ec_a50f_0242ac1c0002row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %% [markdown]
# Age--> Continous Feature

# %%
print('Oldest Passenger was of :', data['Age'].max(), 'Year')
print('Youngest Passenger was of :', data['Age'].min(), 'Year')
print('Average Age on the ship :', data['Age'].mean(), 'Year')
# Out:
# Oldest Passenger was of : 80.0 Year
# Youngest Passenger was of : 0.42 Year
# Average Age on the ship : 29.69911764705882 Year

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot('Pclass', 'Age', hue='Survived', scale='count',  data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot('Sex', 'Age', hue='Survived', scale='count',  data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# ''What's In A Name??''---> Feature :p

# %%
data['Initial'] = 0
